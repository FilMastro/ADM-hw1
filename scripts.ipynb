# %%
# Say "Hello, World!" With Python
print("Hello, World!")

# %%
#Python If-Else
#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    n = int(input().strip())
    if n % 2!= 0:
        print("Weird")
    elif n % 2==0 and n>=2 and n <=5:
        print("Not Weird")
    elif n % 2==0 and n>=6 and n <=20:
        print("Weird")
    elif n % 2==0 and n>20:
        print("Not Weird")

# %%
#Arithmetic Operators
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a+b)
    print(a-b)
    print(a*b)

# %%
#Python: Division

if __name__ == '__main__':
    a = int(input())
    b = int(input())
    print(a//b)
    print(a/b)

# %%
#Loops
if __name__ == '__main__':
    n = int(input())
    v=range(n)
    for i in v:
        print(i**2)

# %%
#Write a function

def is_leap(year):
    leap = False
    if year % 400==0:
        leap=True
    if year % 4==0 and year % 100!=0:
        leap=True    
    # Write your logic here
    
    return leap

# %%
#Print Function

if __name__ == '__main__':
    n = int(input())
    val=[]
    for i in range(1,n+1):
        val.append(i)
    print(*val,sep="")

# %%
#Word Order

# Enter your code here. Read input from STDIN. Print output to STDOUT

dicti={}
n=input()
for i in range(int(n)):
    word=input()

    if str(word) not in dicti.keys():
        dicti[str(word)]=1
    else:
        dicti[str(word)]+=1    

print(len(dicti))
print(*dicti.values(),sep=' ')

# %%
#Find the Runner-Up Score!

if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    lista=[]
    for i in arr:
       if i not in lista:
            lista.append(i)
    lista=sorted(lista)
    
    print(lista[-2])

# %%
#Nested Lists
if __name__ == '__main__':
    lis=[]
    scr=[]
    names=[]
    mina=100
    for _ in range(int(input())):
        name = input()
        score = float(input())
        scr.append(score)
        get=[name,score]
        lis.append(get)
    target=sorted(set(scr))[1]
    for i in lis:
        if i[1]==target:
            names.append(i[0])
    for i in sorted(names):
        print(i)

# %%
#Finding the percentage

if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()
    lst=student_marks[query_name]
    print("{0:.2f}".format(sum(lst)/(len(lst))))

# %%
#List Comprehensions

if __name__ == '__main__':
    x = int(input())
    y = int(input())
    z = int(input())
    n = int(input())
lst=[[i,j,k] for i in range(x+1) for j in range(y+1) for k in range(z+1) if i+j+k !=n ]
print(lst)

# %%
#Lists

if __name__ == '__main__':
    N = int(input())
    lst=[]
    for i in range(N):
        a=input().split()
        if a[0] == "insert":
            lst.insert(int(a[1]),int(a[2]))
        elif a[0] == "pop":
            lst.pop()
        elif a[0] == "print":    
            print(lst)
        elif a[0] == "sort":
            lst.sort()
        elif a[0] == "append":
            lst.append(int(a[1]))
        elif a[0] == "remove":
            lst.remove(int(a[1]))
        elif a[0] == "reverse":
            lst.reverse()

# %%
#Tuples

if __name__ == '__main__':
    n = int(raw_input())
    integer_list = map(int, raw_input().split())
    lst=[i for i in integer_list]
    tup=tuple(lst)
    print(hash(tup))

# %%
#sWAP cASE

def swap_case(s):
    s=s.swapcase()
    return s

# %%
#String Split and Join

def split_and_join(line):
    line=line.split(" ")
    line="-".join(line)
    return line
    # write your code here

# %%
#What's Your Name?

#
# Complete the 'print_full_name' function below.
#
# The function is expected to return a STRING.
# The function accepts following parameters:
#  1. STRING first
#  2. STRING last
#

def print_full_name(first, last):
    txt="Hello {} {}! You just delved into python.".format(first,last)
    print(txt)
    return txt
    # Write your code here

# %%
#Mutations

def mutate_string(string, position, character):
    lst=list(string)
    lst[position]=character
    steerrr=''.join(lst)
    return steerrr

# %%
#String Validators

if __name__ == '__main__':
    inp=[0,0,0,0,0]
    s = input()
    for lettera in s:

        if lettera.isalnum()==True:
            inp[0]=1
        if lettera.isalpha()==True:
            inp[1]=1
        if lettera.isdigit()==True:
            inp[2]=1
        if lettera.islower()==True:
            inp[3]=1
        if lettera.isupper()==True:
            inp[4]=1
    

    for i in inp:
        if i==1:
            print(True)
        else:
            print(False)

# %%
#Text Alignment

#Replace all ______ with rjust, ljust or center. 

thickness = int(input()) #This must be an odd number
c = 'H'

#Top Cone
for i in range(thickness):
    print((c*i).rjust(thickness-1)+c+(c*i).ljust(thickness-1))

#Top Pillars
for i in range(thickness+1):
    print((c*thickness).center(thickness*2)+(c*thickness).center(thickness*6))

#Middle Belt
for i in range((thickness+1)//2):
    print((c*thickness*5).center(thickness*6))    

#Bottom Pillars
for i in range(thickness+1):
    print((c*thickness).center(thickness*2)+(c*thickness).center(thickness*6))    

#Bottom Cone
for i in range(thickness):
    print(((c*(thickness-i-1)).rjust(thickness)+c+(c*(thickness-i-1)).ljust(thickness)).rjust(thickness*6))

# %%
#Text Wrap



def wrap(string, max_width):
    s=textwrap.wrap(string,   width=max_width)
    print(*s,   sep='\n')
    return ''

# %%
#Designer Door Mat

# Enter your code here. Read input from STDIN. Print output to STDOUT
N,M=input().split()
N=int(N)
a=int((int(N)-1)/2)
alam=[x for x in range(int(-(int(N)-1)/2),0)]
blam=[x for x in range(1,int(N)-1,2)]
for i in range(0,a):
    print(abs(alam[i])*3*'-'+blam[i]*'.|.'+abs(alam[i])*3*'-')

f=(3*abs(alam[1])+1)
print(f*'-'+'WELCOME'+f*'-')

alam.reverse()
blam.reverse()

for i in range(0,a):
    print(abs(alam[i])*3*'-'+blam[i]*'.|.'+abs(alam[i])*3*'-')

# %%
#String Formatting

def print_formatted(number):
    # your code goes here
    wid = len("{0:b}".format(number))
    for i in range(1,number+1):
       print("{0:{width}} {0:{width}o} {0:{width}X} {0:{width}b}".format(i,width=wid))

# %%
#Alphabet Rangoli

def print_rangoli(size):
    # your code goes here
    alpha="abcdefghijklmnopqrstuvwxyz"
    L = []
    for i in range(size):
        s = "-".join(alpha[i:n])
        L.append((s[::-1]+s[1:]).center(4*n-3, "-"))
    print('\n'.join(L[:0:-1]+L))

# %%
#Capitalize!



# Complete the solve function below.
def solve(s):
    L=s.split(sep=' ')
    for i in range(len(L)):
        L[i]=L[i].capitalize()
  
    return ' '.join(L)

# %%
#The Minion Game


def minion_game(string):
    vowel =['A','E','I','O','U']
    S=0
    K=0
    for i in range(len(string)):
        if string[i] in vowel:
            K+= len(string)-i
        else:
            S+=len(string)-i
    if S>K:
        print("Stuart"+" "+ "%d" % S)
    elif K>S:
        print("Kevin"+" "+'%d' % K)
    else:
        print("Draw")

# %%
#Find a string

def count_substring(string, sub_string):
    results = 0
    sub_len = len(sub_string)
    for i in range(len(string)):
        if string[i:i+sub_len] == sub_string:
            results += 1    
    return results

# %%
#Merge the Tools!

def merge_the_tools(string, k):
    # your code goes here
    lst=[string[i:i+k] for i in range(0,len(string),k)]

    for i in lst:
        a=[]
        for j in i:
            if j not in a:
                a.append(j) 
        print(''.join(a))

# %%
#Introduction to Sets

def average(array):
    a=set(array)
    return sum(a)/len(a)

# %%
#Symmetric Difference

M=input()
setm=input().split()
setm=set(map(int,setm))
N=input()
setn=input().split()
setn=set(map(int,setn))
result=set()
result=setm.symmetric_difference(setn)
result=sorted(result)
for i in result:
    print(i)

# %%
#No Idea!

N,M=input().split()
s=input().split()
reference=list(map(int,s))
A=input().split()
A=list(map(int,A))
A=set(A)
B=input().split()
B=list(map(int,B))
B=set(B)
hap=0
for i in reference:
    if i in A:
        hap+=1
    if i in B:
        hap-=1
print(hap)

# %%
#Set .add()

N=int(input())
countries=set()
for i in range(N):
    stamp=input()
    countries.add(stamp)
print(len(countries))

# %%
#Set .discard(), .remove() & .pop()

n = int(input())
s = set(map(int, input().split()))
sputs=int(input())
for i in range(sputs):
    lst=list(input().split())
    if lst[0]=='pop':
        s.pop()
    if lst[0]=='discard':
        s.discard(int(lst[1]))
    if lst[0]=='remove':
        s.remove(int(lst[1]))
print(sum(s))

# %%
#Set .union() Operation

n=int(input())
eng=set(input().split())
b=int(input())
fr=set(input().split())
res=eng.union(fr)
print(len(res))

# %%
#Set .intersection() Operation

n=int(input())
eng=set(input().split())
b=int(input())
fr=set(input().split())
res=eng.intersection(fr)
print(len(res))

# %%
#Set .difference() Operation

n=int(input())
eng=set(input().split())
b=int(input())
fr=set(input().split())
res=eng.difference(fr)
print(len(res))

# %%
#Set .symmetric_difference() Operation

n=int(input())
eng=set(input().split())
b=int(input())
fr=set(input().split())
res=eng.symmetric_difference(fr)
print(len(res))

# %%
#Set Mutations

lenA=int(input())
A=input().split()
A=set(map(int,A))
N=int(input())
for i in range(N):
    cmd=list(input().split())
    if cmd[0]=="update":
        s=input().split()
        s=set(map(int,s))
        A.update(s)
    if cmd[0]=="intersection_update":
        s=input().split()
        s=set(map(int,s))
        A.intersection_update(s)
    if cmd[0]=="difference_update":
        s=input().split()
        s=set(map(int,s))
        A.difference_update(s)
    if cmd[0]=="symmetric_difference_update":
        s=input().split()
        s=set(map(int,s))
        A.symmetric_difference_update(s)
print(sum(A))

# %%
#The Captain's Room

K=int(input())
L=(input().split())
L=list(map(int,L))
S=set(L)
for i in S:
    L.remove(i)
L=set(L)
S.difference_update(L)
for i in S:
    print(i)

# %%
#Check Subset

T=int(input())
for i in range(T):
    lenA=int(input())
    A=input().split()
    A=set(map(int,A))
    lenB=int(input())
    B=input().split()
    B=set(map(int,B))
    if A.intersection(B)==A:
        print(True)
    else:
        print(False)

# %%
#Check Strict Superset

A=input().split()
A=set(map(int,A))
n=int(input())
count=0
for i in range(n):
    B=input().split()
    B=set(map(int,B))
    if A.intersection(B)!= A and B.intersection(A)==B:
        count+=1
if count==n:
    print(True)
else:
    print(False)

# %%
#collections.Counter()

from collections import Counter
X=int(input())
shoes=list(map(int,input().split())) 
N=int(input())
ricavo=0
for i in range (N):
    s=list(input().split())
    if int(s[0]) in shoes:
        shoes.remove(int(s[0]))
        ricavo+=int(s[1])
print(ricavo)

# %%
#DefaultDict Tutorial

from collections import defaultdict
n,m=input().split()
n=int(n)
m=int(m)
d=defaultdict(list)
sist=[]
for i in range(n):
    s=input()
    d[s].append(i+1)
for i in range(m):
    s=input()
    sist.append(s)
    
for j in sist:
    if j in d:
        print (" ".join( map(str,d[j]) ))
    else:
        print (-1)

# %%
#Collections.namedtuple()

# Enter your code here. Read input from STDIN. Print output to STDOUT
from collections import namedtuple
N=int(input())
Stud=namedtuple('Stud',input())
counter=0
for i in range(N):
    inn=list(input().split())
    s=Stud(inn[0],inn[1],inn[2],inn[3])
    counter+=int(s.MARKS)
print("%.2f" % round(int(counter)/N,2))

# %%
#Collections.OrderedDict()

from collections import OrderedDict
N=int(input())
supermarket=OrderedDict()
for i in range(N):
    inp=list(input().split())
    if ' '.join(inp[0:-1]) not in supermarket:
        supermarket[' '.join(inp[0:-1])]=int(inp[-1])
    else:
        supermarket[' '.join(inp[0:-1])]+=int(inp[-1])
for i in supermarket:
    print(' '.join([i,str(supermarket[i])]))

# %%
#Collections.deque()

from collections import deque
N=int(input())
a=deque()
for i in range(N):
    inn=list(input().split())
    if inn[0]=='append':
        a.append(inn[1])
    if inn[0]=='appendleft':
        a.appendleft(inn[1])
    if inn[0]=='pop':
        a.pop()
    if inn[0]=='popleft':
        a.popleft()
print(' '.join(a))

# %%
#Company Logo

#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    s = input()
    Dict={}
    for x in sorted(s):
        Dict[x]=Dict.get(x,0)+1   
#Sorting Dict by value & storing sorted keys in Dict_keys.
    Dict_keys=sorted(Dict, key=Dict.get, reverse=True)  

    for key in Dict_keys[:3]:
        print(key,Dict[key])

# %%
#Calendar Module

import calendar
s=list(input().split())
weekdays=['MONDAY','TUESDAY','WEDNESDAY','THURSDAY','FRIDAY','SATURDAY','SUNDAY']
ama=calendar.TextCalendar(0)
print(weekdays[calendar.weekday(int(s[2]),int(s[0]),int(s[1]))])

# %%
#Time Delta

#!/bin/python3
from datetime import datetime
import math
import os
import random
import re
import sys

# Complete the time_delta function below.
def time_delta(t1, t2):
    fmt = '%a %d %b %Y %H:%M:%S %z'
    t1=datetime.strptime(t1,fmt)
    t2=datetime.strptime(t2,fmt)
  
    
    return (str(int(abs((t1-t2).total_seconds()))))

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input())

    for t_itr in range(t):
        t1 = input()

        t2 = input()

        delta = time_delta(t1, t2)

        fptr.write(delta + '\n')

    fptr.close()

# %%
#Exceptions
T=int(input())
for i in range(T):
    
    try:
        a,b=map(int,input().split())
        print(a//b)
    except ZeroDivisionError as e:
        print ("Error Code:",e)
    except ValueError as g:
        print ("Error Code:",g)

# %%
#Zipped!

N,X=map(int,input().split())
biggie=[]
for i in range(X):
    l=list(map(float,input().split()))
    biggie.append(l)
a=list(zip(*biggie))
for i in a:
    print(sum(i)/X)

# %%
#Athlete Sort

#!/bin/python3

import math
import os
import random
import re
import sys



if __name__ == '__main__':
    nm = input().split()

    n = int(nm[0])

    m = int(nm[1])

    arr = []

    for _ in range(n):
        arr.append(list(map(int, input().rstrip().split())))

    k = int(input())
    
    arr.sort(key=lambda x: x[k])

    for line in arr:
        print(*line, sep=' ')

# %%
#ginortS

s=input()
alpha='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ1357902468'
print(*sorted(s, key=alpha.index), sep='')

# %%
#Map and Lambda Function

cube = lambda x: x**3# complete the lambda function 

def fibonacci(n):
    # return a list of fibonacci numbers
    l=[0]
    x=1
    y=0
    for i in range(n):
        x=x+y
        y=x+y
        l.append(x)
        l.append(y)
    return(l[:n])

# %%
#Piling Up!

from collections import deque
T=int(input())
for i in range(T):
    n=int(input())
    a=deque(map(int,input().split()))
    while a:
        big = a.popleft() if a[0]>a[-1] else a.pop()
        if not a:
            print("Yes")
            break
        if a[-1]>big or a[0]>big:
            print("No")
            break

# %%
#Detect Floating Point Number

import re
T=int(input())
for i in range(T):
    test=input()
    p=re.compile(r'^[+-.]?[0-9]*\.[0-9]+$')
    print(bool(p.search(test)))

# %%
#Re.split()

regex_pattern = r"[.,]"	# Do not delete 'r'.

# %%
#Group(), Groups() & Groupdict()

import re
p=re.compile(r'((\w(?!_)))\1+')
m=p.search(input().strip())
print(m.group(1) if m else -1)

# %%
#Re.findall() & Re.finditer()

import re
s=input()
p=re.compile(r'(?<=[QWRTYPSDFGHJKLZXCVBNMqwrtypsdfghjklzxcvbnm+])([aeiouAEIOU]{2,})[QWRTYPSDFGHJKLZXCVBNMqwrtypsdfghjklzxcvbnm]')
lst=re.findall(p,s)
if len(lst)==0:
    print (-1)
else:
    print(*lst ,sep='\n')

# %%
#Re.start() & Re.end()

import re
s=input()
k=input()
m=re.search(k,s)
if not m:
    print((-1,-1))
while m:
    print((m.start(),m.end()-1))
    p=re.compile(k)
    m=p.search(s,m.start()+1)

# %%
#Regex Substitution

import re
N=int(input())
for i in range(N):
    s=input()
    s=re.sub(r'(?<= )(&&)(?= )',lambda expr: 'and' if expr.group() == '&&' else '',s)
    s=re.sub(r'(?<= )(\|\|)(?= )',lambda expr: 'or' if expr.group() == '||' else '',s)
    print(s)

# %%
#Validating Roman Numerals

regex_pattern = r"^(?=[MDCLXVI])M{0,3}(C[MD]|D?C{0,3})(X[CL]|L?X{0,3})(I[XV]|V?I{0,3})$"	# Do not delete 'r'.

# %%
#Validating phone numbers

import re
N=int(input())
p=re.compile(r'^[789]\d{9}$')
for i in range(N):
    num=input()
    a=p.match(num)
    if a:
        print("YES")
    else:
        print('NO')

# %%
#Validating and Parsing Email Addresses

N=int(input())
import re 
import email.utils
p=re.compile(r'^[a-zA-Z][a-zA-z0-9,-_]*(?<!\@)\@(?!\@)[a-zA-Z]*\.[a-zA-Z]{1,3}$')
for i in range (N):
    name, emai=input().split(' ')
    emai=emai.strip('<>')
    t=(name,emai)
    if p.match(t[1]):
        
        print(email.utils.formataddr(t))
    else:
        pass

# %%
#Hex Color Code

import re
n=int(input())
for i in range(n):
    for j in re.findall('[\s:](#[a-f0-9]{6}|#[a-f0-9]{3})', input(), re.I):
        print(j)

# %%
#HTML Parser - Part 1

from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):        
        print ('Start :',tag)
        for ele in attrs:
            print ('->',ele[0],'>',ele[1])
            
    def handle_endtag(self, tag):
        print ('End   :',tag)
        
    def handle_startendtag(self, tag, attrs):
        print ('Empty :',tag)
        for ele in attrs:
            print ('->',ele[0],'>',ele[1])
            
MyParser = MyHTMLParser()
MyParser.feed(''.join([input().strip() for i in range(int(input()))]))

# %%
#HTML Parser - Part 2

from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    def handle_comment(self, data):
        if (len(data.split('\n')) != 1):
            print(">>> Multi-line Comment")
        else:
            print(">>> Single-line Comment")
        print(data.replace("\r", "\n"))
    def handle_data(self, data):
        if data.strip():
            print(">>> Data")
            print(data) 
html = ""       
for i in range(int(input())):
    html += input().rstrip()
    html += '\n'
    
parser = MyHTMLParser()
parser.feed(html)
parser.close()

# %%
#Detect HTML Tags, Attributes and Attribute Values

from html.parser import HTMLParser
class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print(tag)
        [print('-> {} > {}'.format(*attr)) for attr in attrs]
        
html = '\n'.join([input() for _ in range(int(input()))])
parser = MyHTMLParser()
parser.feed(html)
parser.close()

# %%
#Validating UID

import re
n=int(input())
p=re.compile(r'^(?=(?:[a-z\d]*[A-Z]){2})(?=(?:\D*\d){3})(?:([a-zA-Z\d])(?!.*\1)){10}$')
for i in range(n):
    s=input()
    if p.match(s):
        print('Valid')
    else:
        print('Invalid')

# %%
#Validating Credit Card Numbers

n=int(input())
import re
p=re.compile(r'^(?!.*(\d)(-?\1){3})[456]\d{3}(?:-?\d{4}){3}$')
for i in range(n):
    
    if p.match(input()):
        print('Valid')
    else :print('Invalid')

# %%
#Validating Postal Codes

regex_integer_in_range = r"^[1-9][\d]{5}$"	# Do not delete 'r'.
regex_alternating_repetitive_digit_pair = r"(\d)(?=\d\1)"	# Do not delete 'r'.

# %%
#Matrix Script

#!/bin/python3

import math
import os
import random
import re
import sys




first_multiple_input = input().rstrip().split()

n = int(first_multiple_input[0])

m = int(first_multiple_input[1])

matrix = []

for _ in range(n):
    matrix_item = input()
    matrix.append(matrix_item)
    
    
strong = "".join([matrix[j][i] for i in range(m) for j in range(n)])
p=r'(?<=[a-zA-Z0-9])[^a-zA-Z0-9]+(?=[a-zA-Z0-9])'
print(re.sub(p,' ',strong))

# %%
#XML 1 - Find the Score
def get_attr_number(node):
    num=len(node.attrib)
    for i in node:
        num+=get_attr_number(i)
    return num

# %%
#XML2 - Find the Maximum Depth



maxdepth = 0
def depth(elem, level):
    global maxdepth
    if (level==maxdepth):
        maxdepth+=1
    for i in elem:
        depth(i,level+1)
    # your code goes here

# %%
#Standardize Mobile Number Using Decorators

def wrapper(f):
    def fun(l):
        
        l =  ["+91 " + i[-10:-5] + " " + i[-5:] for i in l]
        return f(l)
    
    return fun

# %%
#Decorators 2 - Name Directory



def person_lister(f):
    def inner(people):
        return (f(person) for person in sorted(people, key=lambda x: int(x[2])))
    return inner

# %%
#Arrays

def arrays(arr):
    arr=numpy.array(arr,float)
    return numpy.flip(arr)

# %%
#Shape and Reshape

import numpy as np
arr=np.array(input().split(),int)
arr.shape=(3,3)
print(arr)

# %%
#Transpose and Flatten

import numpy as np
N,M= map(int, input().split())
arr=[]
for i in range (N):
    ls=list(map(int,input().split()))
    arr.append(ls)

arr=np.array(arr)
print(arr.transpose())
print(arr.flatten())

# %%
#Concatenate

import numpy as np
N,M,P=list(map(int,input().split()))
enpi=[]
empi=[]
for i in range (N):
    ls=list(map(int,input().split()))
    enpi.append(ls)
for j in range (M):
    ls=list(map(int,input().split()))
    empi.append(ls)

enpi=np.array(enpi,int)
empi=np.array(empi,int)
    
print(np.concatenate((enpi,empi)))

# %%
#Zeros and Ones

import numpy as np

ls=tuple(map(int,input().split()))
print(np.zeros(ls,int))
print(np.ones(ls,int))

# %%
#Eye and Identity

import numpy as np
np.set_printoptions(legacy='1.13')
N,M=map(int,input().split())
print(np.eye(N,M))

# %%
#Array Mathematics

import numpy as np
import sys
N,M=map(int,input().split())
A = np.array([input().split() for i in range(N)],int)
B = np.array([input().split() for j in range(N)],int)



print(np.add(A,B))
print(np.subtract(A,B))
print(np.multiply(A,B))
print(np.floor_divide(A,B))
print(np.mod(A,B))
print(np.power(A,B))

# %%
#Floor, Ceil and Rint

import numpy as np
np.set_printoptions(legacy='1.13')
my_array = np.array(input().split(),float)
print(np.floor(my_array))
print(np.ceil(my_array))
print(np.rint(my_array))

# %%
#Sum and Prod

import numpy as np
shape=tuple(map(int,input().split()))
A=np.array([input().split() for i in range(shape[0])],int)
su=np.sum(A,0)
print(np.prod(su))

# %%
#Min and Max

import numpy as np

shape=tuple(map(int,input().split()))
A=np.array([input().split() for i in range(shape[0])],int)
su=np.min(A,1)
print(np.max(su))

# %%
#Mean, Var, and Std

import numpy as np
#np.set_printoptions(legacy='1.13')
shape=tuple(map(int,input().split()))
A=np.array([input().split() for i in range(shape[0])],int)
print(np.mean(A,1))
print(np.var(A,0))
print(round(np.std(A),11))

# %%
#Dot and Cross

import numpy as np
N=int(input())
A=np.array([input().split() for i in range(N)],int)
B=np.array([input().split() for i in range(N)],int)
M=np.zeros((N,N),int)
for i in range(N):
    for j in range(N):
        M[i][j]=int(np.dot(A[i],B[:,j]))
print(M)

# %%
#Inner and Outer

import numpy as np
A=np.array(input().split(),int)
B=np.array(input().split(),int)

print(np.inner(A,B))
print(np.outer(A,B))

# %%
#Polynomials

import numpy as np
A=np.array(input().split(),float)
print (np.polyval(A, float(input())))

# %%
#Linear Algebra

import numpy as np
n=int(input())
A=np.array([input().split() for i in range(n)],float)

print(round(np.linalg.det(A),2))

# %%
#Birthday Cake Candles

#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'birthdayCakeCandles' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER_ARRAY candles as parameter.
#

def birthdayCakeCandles(candles):
    dictqa={}
    for i in candles:
        if i in dictqa:
            dictqa[i]+=1
        else:
            dictqa[i]=1
    a=max(dictqa.keys())
    return dictqa[a]
    
    
    
if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    candles_count = int(input().strip())

    candles = list(map(int, input().rstrip().split()))

    result = birthdayCakeCandles(candles)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#Number Line Jumps

#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'kangaroo' function below.
#
# The function is expected to return a STRING.
# The function accepts following parameters:
#  1. INTEGER x1
#  2. INTEGER v1
#  3. INTEGER x2
#  4. INTEGER v2
#

def kangaroo(x1, v1, x2, v2):
    if x1!=x2 and v1==v2:
        return "NO"
    if (x2-x1)%(v1-v2)==0 and (x2-x1)//(v1-v2)>0:
        return "YES"
    else:
        return "NO"
      

    

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    x1 = int(first_multiple_input[0])

    v1 = int(first_multiple_input[1])

    x2 = int(first_multiple_input[2])

    v2 = int(first_multiple_input[3])

    result = kangaroo(x1, v1, x2, v2)

    fptr.write(result + '\n')

    fptr.close()

# %%
#Viral Advertising

#!/bin/python3

import math
import os
import random
import re
import sys


#
# Complete the 'viralAdvertising' function below.
#
# The function is expected to return an INTEGER.
# The function accepts INTEGER n as parameter.
#

def viralAdvertising(n):
    cum=[]
    unit=5
    for i in range(n):
        lik=math.floor(unit/2)
        unit=lik*3
        cum.append(lik)
    
    return sum(cum)

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    n = int(input().strip())

    result = viralAdvertising(n)

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
#Recursive Digit Sum

#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'superDigit' function below.
#
# The function is expected to return an INTEGER.
# The function accepts following parameters:
#  1. STRING n
#  2. INTEGER k
#

def superDigit(n, k):
    n=sum([int(x) for x in str(n)])
    n=n*k

    if n>=10:
        return superDigit(n,1)
    else:
        return n

        
        
        
        

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    first_multiple_input = input().rstrip().split()

    n = first_multiple_input[0]

    k = int(first_multiple_input[1])

    result = superDigit(n, k)
    

    fptr.write(str(result) + '\n')

    fptr.close()

# %%
Insertion Sort - Part 1

#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'insertionSort1' function below.
#
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY arr
#

def insertionSort1(n, arr):
    for i in range(1, n):
        temp = arr[i]
        j = i
        while j > 0 and arr[j-1] > temp:
            arr[j] = arr[j-1]
            j = j - 1
            print(*arr)
        arr[j] = temp
    print(*arr)

if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort1(n, arr)

# %%
Insertion Sort - Part 2

#!/bin/python3

import math
import os
import random
import re
import sys

#
# Complete the 'insertionSort2' function below.
#
# The function accepts following parameters:
#  1. INTEGER n
#  2. INTEGER_ARRAY arr
#

def insertionSort2(n, arr):
    for i in range(1,n):
        l=arr[:i+1]
        l=sorted(l)
        res=l+arr[i+1:]
        print(*res)

if __name__ == '__main__':
    n = int(input().strip())

    arr = list(map(int, input().rstrip().split()))

    insertionSort2(n, arr)
